# %%
import matplotlib.pyplot as plt
import pickle as pkl
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-9055a30d9d86> in <module>
# ----> 1 import matplotlib.pyplot as plt
#       2 import pickle as pkl
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
with open('./rewards/rewards (3) (1).pkl', 'rb') as f:
    rewards = pkl.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-bca1a2925ac5> in <module>
# ----> 1 with open('./rewards/rewards (3) (1).pkl', 'rb') as f:
#       2     rewards = pkl.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: './rewards/rewards (3) (1).pkl'

# %%
coef = np.polyfit(range(len(rewards)), rewards, 1)
poly1d_fn = np.poly1d(coef)
x = range(len(rewards))

# %%
plt.plot(x,rewards, x, poly1d_fn(x), '--k')
#plt.plot(rewards)
plt.ylabel("Reward")
plt.xlabel("Round")
plt.show()
