# %%
import matplotlib.pyplot as plt
import pickle as pkl

# %%
with open('./rewards/rewards.pkl', 'rb') as f:
    rewards = pkl.load(f)

# %%
plt.plot(rewards)
plt.ylabel("Reward")
plt.xlabel("Round")
plt.show()
