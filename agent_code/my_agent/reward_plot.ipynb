# %%
import matplotlib.pyplot as plt
import pickle as pkl

# %%
with open('rewards.pkl', 'rb') as f:
    rewards = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-03242a5b3971> in <module>
# ----> 1 with open('rewards.pkl', 'rb') as f:
#       2     rewards = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rewards.pkl'

# %%
plt.plot(rewards)
plt.ylabel("Reward")
plt.xlabel("Round")
plt.show()
